# %% [markdown]
# # [한국투자 Open API](https://apiportal.koreainvestment.com/apiservice-summary)

# %%
from blsh.kis import kis_auth as ka
from blsh.kis.domestic_stock import domestic_stock_functions as ds

# 인증
# ka.auth(svr="vps")
ka.auth(svr="prod")
trenv = ka.getTREnv()

# %% [markdown]
# ## **국내주식**
# ---

# %% [markdown]
# ### **1. 주문/계좌**

# %% [markdown]
# #### 1-1. 주식주문(현금) [v1_국내주식-001]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식주문(현금)[v1_국내주식-001]
##############################################################################################
ds.order_cash(env_dv="real", ord_dv="sell", cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, pdno="005930",
                    ord_dvsn="00", ord_qty="1", ord_unpr="2000", excg_id_dvsn_cd="SOR")
# Out:
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/trading/order-cash
# rt_cd :  7 / msg_cd :  APBK0919 / msg1 :  장운영일자가 주문일과 상이합니다
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 1-2. 주식주문(신용) [v1_국내주식-002]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식주문(신용)[v1_국내주식-002]
##############################################################################################
ds.order_credit(
    ord_dv="buy",
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    pdno="005930",
    crdt_type="21",
    loan_dt="20220810",
    ord_dvsn="00",
    ord_qty="1",
    ord_unpr="55000"
)
# Out:
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/trading/order-credit
# rt_cd :  7 / msg_cd :  APBK2107 / msg1 :  신용 미개설(약정)계좌는 신용주문 불가합니다. (신용계좌유형코드)
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 1-3. 주식주문(정정취소) [v1_국내주식-003]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식주문(정정취소)[v1_국내주식-003]
##############################################################################################
ds.order_rvsecncl(
    env_dv="real",
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    krx_fwdg_ord_orgno="06010",
    orgn_odno="0000002101",
    ord_dvsn="00",
    rvse_cncl_dvsn_cd="02",
    ord_qty="1",
    ord_unpr="55000",
    qty_all_ord_yn="Y",
    excg_id_dvsn_cd="KRX"
)
# Out:
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/trading/order-rvsecncl
# rt_cd :  7 / msg_cd :  APBK0344 / msg1 :  원주문정보가 존재하지않습니다.
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 1-4. 주식정정취소가능주문조회 [v1_국내주식-004]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식정정취소가능주문조회[v1_국내주식-004]
##############################################################################################
ds.inquire_psbl_rvsecncl(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, inqr_dvsn_1="1", inqr_dvsn_2="0")
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 1-5. 주식일별주문체결조회 [v1_국내주식-005]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식일별주문체결조회[v1_국내주식-005]
##############################################################################################
result1, result2 = ds.inquire_daily_ccld(
    env_dv="real",
    pd_dv="inner",
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    inqr_strt_dt="20220810",
    inqr_end_dt="20220810",
    sll_buy_dvsn_cd="00",
    inqr_dvsn="00",
    pdno="005930",
    ccld_dvsn="00",
    inqr_dvsn_3="00"
)
print(result1)
print(result2)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []
#   tot_ord_qty tot_ccld_qty tot_ccld_amt prsm_tlex_smtl pchs_avg_pric
# 0           0            0            0              0        0.0000

# %% [markdown]
# #### 1-6. 주식예약주문 [v1_국내주식-017]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식예약주문[v1_국내주식-017]
##############################################################################################
ds.order_resv(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, pdno="005930", ord_qty="1", ord_unpr="55000",
                    sll_buy_dvsn_cd="02", ord_dvsn_cd="00", ord_objt_cblc_dvsn_cd="10")
# Out:
#   RSVN_ORD_SEQ
# 0       150927

# %% [markdown]
# #### 1-7. 주식예약주문정정취소 [v1_국내주식-018,019]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식예약주문정정취소[v1_국내주식-018,019]
##############################################################################################
ds.order_resv_rvsecncl(
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    rsvn_ord_seq="88793",
    rsvn_ord_orgno="001",
    rsvn_ord_ord_dt="20250113",
    ord_type="cancel",
    pdno="005930",
    ord_qty="2",
    ord_unpr="55000",
    sll_buy_dvsn_cd="02",
    ord_dvsn_cd="00",
    ord_objt_cblc_dvsn_cd="10"
)
# Out:
#   NRML_PRCS_YN
# 0            Y

# %% [markdown]
# #### 1-8. 주식예약주문조회 [v1_국내주식-020]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식예약주문조회[v1_국내주식-020]
##############################################################################################
ds.order_resv_ccnl(
    rsvn_ord_ord_dt="20220729",
    rsvn_ord_end_dt="20220810",
    tmnl_mdia_kind_cd="00",
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    prcs_dvsn_cd="0",
    cncl_yn="Y"
)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 1-9. 주식잔고조회 [v1_국내주식-006]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식잔고조회[v1_국내주식-006]
##############################################################################################
result1, result2 = ds.inquire_balance(
    env_dv="real",
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    afhr_flpr_yn="N",
    inqr_dvsn="01",
    unpr_dvsn="01",
    fund_sttl_icld_yn="N",
    fncg_amt_auto_rdpt_yn="N",
    prcs_dvsn="00"
)
print(result1)
print(result2)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []
#   dnca_tot_amt nxdy_excc_amt prvs_rcdl_excc_amt cma_evlu_amt bfdy_buy_amt  \
# 0            0             0                  0            0            0
#
#   thdt_buy_amt nxdy_auto_rdpt_amt bfdy_sll_amt thdt_sll_amt d2_auto_rdpt_amt  \
# 0            0                  0            0            0                0
#
#    ... tot_evlu_amt nass_amt fncg_gld_auto_rdpt_yn pchs_amt_smtl_amt  \
# 0  ...            0        0                                       0
#
#   evlu_amt_smtl_amt evlu_pfls_smtl_amt tot_stln_slng_chgs  \
# 0                 0                  0                  0
#
#   bfdy_tot_asst_evlu_amt asst_icdc_amt asst_icdc_erng_rt
# 0                      0             0        0.00000000
#
# [1 rows x 24 columns]

# %% [markdown]
# #### 1-10. 주식잔고조회_실현손익 [v1_국내주식-041]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식잔고조회_실현손익[v1_국내주식-041]
##############################################################################################
result1, result2 = ds.inquire_balance_rlz_pl(
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    afhr_flpr_yn="N",
    inqr_dvsn="02",
    unpr_dvsn="01",
    fund_sttl_icld_yn="N",
    fncg_amt_auto_rdpt_yn="N",
    prcs_dvsn="01",
    cost_icld_yn="N"
)
print(result1)
print(result2)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []
#   dnca_tot_amt nxdy_excc_amt prvs_rcdl_excc_amt cma_evlu_amt bfdy_buy_amt  \
# 0            0             0                  0            0            0
#
#   thdt_buy_amt nxdy_auto_rdpt_amt bfdy_sll_amt thdt_sll_amt d2_auto_rdpt_amt  \
# 0            0                  0            0            0                0
#
#    ... evlu_amt_smtl_amt evlu_pfls_smtl_amt tot_stln_slng_chgs  \
# 0  ...                 0                  0                  0
#
#   bfdy_tot_asst_evlu_amt asst_icdc_amt asst_icdc_erng_rt rlzt_pfls  \
# 0                      0             0        0.00000000         0
#
#   rlzt_erng_rt real_evlu_pfls real_evlu_pfls_erng_rt
# 0   0.00000000              0             0.00000000
#
# [1 rows x 28 columns]

# %% [markdown]
# #### 1-11. 매수가능조회 [v1_국내주식-007]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 매수가능조회[v1_국내주식-007]
##############################################################################################
ds.inquire_psbl_order(env_dv="real", cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, pdno="005930",
                            ord_unpr="55000",
                            ord_dvsn="01", cma_evlu_amt_icld_yn="N", ovrs_icld_yn="N")
# Out:
#   ord_psbl_cash ord_psbl_sbst ruse_psbl_amt fund_rpch_chgs psbl_qty_calc_unpr  \
# 0             0             0             0              0             283000
#
#   nrcvb_buy_amt nrcvb_buy_qty max_buy_amt max_buy_qty cma_evlu_amt  \
# 0             0             0           0           0            0
#
#   ovrs_re_use_amt_wcrc ord_psbl_frcr_amt_wcrc
# 0                    0                      0

# %% [markdown]
# #### 1-12. 매도가능수량조회 [국내주식-165]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 매도가능수량조회 [국내주식-165]
##############################################################################################
ds.inquire_psbl_sell(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, pdno="000660")
# Out:
# INFO - Data fetch complete.
#      pdno prdt_name buy_qty sll_qty cblc_qty nsvg_qty ord_psbl_qty  \
# 0  000660                 0       0        0        0            0
#
#   pchs_avg_pric pchs_amt now_pric evlu_amt evlu_pfls_amt evlu_pfls_rt
# 0        0.0000        0        0        0             0         0.00

# %% [markdown]
# #### 1-13. 신용매수가능조회 [v1_국내주식-042]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 신용매수가능조회[v1_국내주식-042]
##############################################################################################
ds.inquire_credit_psamount(
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    pdno="005930",
    ord_dvsn="00",
    crdt_type="21",
    cma_evlu_amt_icld_yn="N",
    ovrs_icld_yn="N"
)
# Out:
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/trading/inquire-credit-psamount
# rt_cd :  4 / msg_cd :  APBK1617 / msg1 :  신용계좌만 신용주문가능금액조회가 가능합니다.
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 1-14. 기간별손익일별합산조회 [v1_국내주식-052]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 기간별손익일별합산조회[v1_국내주식-052]
##############################################################################################
result1, result2 = ds.inquire_period_profit(
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    inqr_strt_dt="20230101",
    inqr_end_dt="20240301",
    sort_dvsn="00",
    inqr_dvsn="00",
    cblc_dvsn="00"
)
print(result1)
print(result2)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []
#   sll_qty_smtl sll_tr_amt_smtl sll_fee_smtl sll_tltx_smtl sll_excc_amt_smtl  \
# 0            0               0            0             0                 0
#
#   buy_qty_smtl buy_tr_amt_smtl buy_fee_smtl buy_tax_smtl buy_excc_amt_smtl  \
# 0            0               0            0            0                 0
#
#   tot_qty tot_tr_amt tot_fee tot_tltx tot_excc_amt tot_rlzt_pfls loan_int
# 0       0          0       0        0            0             0        0

# %% [markdown]
# #### 1-15. 기간별매매손익현황조회 [v1_국내주식-060]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 기간별매매손익현황조회[v1_국내주식-060]
##############################################################################################
result1, result2 = ds.inquire_period_trade_profit(
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    sort_dvsn="02",
    inqr_strt_dt="20230216",
    inqr_end_dt="20240301",
    cblc_dvsn="00"
)
print(result1)
print(result2)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []
#   sll_qty_smtl sll_tr_amt_smtl sll_fee_smtl sll_tltx_smtl sll_excc_amt_smtl  \
# 0            0               0            0             0                 0
#
#   buyqty_smtl buy_tr_amt_smtl buy_fee_smtl buy_tax_smtl buy_excc_amt_smtl  \
# 0           0               0            0            0                 0
#
#   tot_qty tot_tr_amt tot_fee tot_tltx tot_excc_amt tot_rlzt_pfls loan_int  \
# 0       0          0       0        0            0             0        0
#
#     tot_pftrt
# 0  0.00000000

# %% [markdown]
# #### 1-16. 투자계좌자산현황조회 [v1_국내주식-048]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 투자계좌자산현황조회[v1_국내주식-048]
##############################################################################################
result1, result2 = ds.inquire_account_balance(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod)
result1
result2
# Out:
# INFO - Data fetch complete.
#   pchs_amt_smtl nass_tot_amt loan_amt_smtl evlu_pfls_amt_smtl evlu_amt_smtl  \
# 0             0            0             0                  0             0
#
#   tot_asst_amt tot_lnda_tot_ulst_lnda cma_auto_loan_amt tot_mgln_amt  \
# 0            0                      0                 0            0
#
#   stln_evlu_amt  ... cma_evlu_amt dncl_amt tot_sbst_amt thdt_rcvb_amt  \
# 0             0  ...            0        0            0             0
#
#   ovrs_stck_evlu_amt1 ovrs_bond_evlu_amt mmf_cma_mgge_loan_amt sbsc_dncl_amt  \
# 0            0.000000           0.000000                     0             0
#
#   pbst_sbsc_fnds_loan_use_amt etpr_crdt_grnt_loan_amt
# 0                           0                       0
#
# [1 rows x 25 columns]

# %% [markdown]
# #### 1-17. 주식통합증거금 현황 [국내주식-191]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 주식통합증거금 현황 [국내주식-191]
##############################################################################################
ds.intgr_margin(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, cma_evlu_amt_icld_yn="N", wcrc_frcr_dvsn_cd="01",
                      fwex_ctrt_frcr_dvsn_cd="01")
# Out:
#    acmga_rt acmga_pct100_aptm_rson stck_cash_objt_amt stck_sbst_objt_amt  \
# 0  100.0000               고객100%신청             0.0000             0.0000
#
#   stck_evlu_objt_amt stck_ruse_psbl_objt_amt stck_fund_rpch_chgs_objt_amt  \
# 0             0.0000                  0.0000                       0.0000
#
#   stck_fncg_rdpt_objt_atm bond_ruse_psbl_objt_amt stck_cash_use_amt  ...  \
# 0                  0.0000                  0.0000            0.0000  ...
#
#   jpy_frst_bltn_exrt cny_frst_bltn_exrt uk_usd_re_use_objt_amt  \
# 0         9.18390000       209.27000000                   0.00
#
#   uk_usd_re_use_amt uk_usd_re_use_oth_mket_use_amt uk_usd_re_use_ord_psbl_amt  \
# 0              0.00                           0.00                       0.00
#
#   uk_usd_gnrl_ord_psbl_amt uk_usd_itgr_ord_psbl_amt  \
# 0                     0.00                     0.00
#
#   hgkg_cny_gnrl_ord_psbl_amt hgkg_cny_itgr_ord_psbl_amt
# 0                       0.00                       0.00
#
# ...

# %% [markdown]
# #### 1-18. 기간별계좌권리현황조회 [국내주식-211]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 기간별계좌권리현황조회 [국내주식-211]
##############################################################################################
ds.period_rights(inqr_dvsn="01", cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, inqr_strt_dt="20260215",
                       inqr_end_dt="20260219")
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 1-19. 퇴직연금 체결기준잔고 [v1_국내주식-032]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 퇴직연금 체결기준잔고[v1_국내주식-032]
##############################################################################################
result1, result2 = ds.pension_inquire_present_balance(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod,
                                                   user_dvsn_cd="00"
                                                   )
print(result1)
print(result2)
# Out:
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/trading/pension/inquire-present-balance
# rt_cd :  7 / msg_cd :  APAC0489 / msg1 :  위탁계좌인 경우만 조회가능합니다.
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 1-20. 퇴직연금 미체결내역 [v1_국내주식-033]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 퇴직연금 미체결내역[v1_국내주식-033]
##############################################################################################
ds.pension_inquire_daily_ccld(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, user_dvsn_cd="%%",
                                    sll_buy_dvsn_cd="00",
                                    ccld_nccs_dvsn="%%", inqr_dvsn_3="00")
# Out:
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# WARNING - Max recursive depth reached.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 1-21. 퇴직연금 매수가능조회 [v1_국내주식-034]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 퇴직연금 매수가능조회[v1_국내주식-034]
##############################################################################################
ds.pension_inquire_psbl_order(
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    pdno="069500",
    acca_dvsn_cd="00",
    cma_evlu_amt_icld_yn="Y",
    ord_unpr="30800",
    ord_dvsn="00"
)
# Out:
#   ord_psbl_cash ruse_psbl_amt psbl_qty_calc_unpr max_buy_amt max_buy_qty
# 0             0             0              30800           0           0

# %% [markdown]
# #### 1-22. 퇴직연금 예수금조회 [v1_국내주식-035]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 퇴직연금 예수금조회[v1_국내주식-035]
##############################################################################################
ds.pension_inquire_deposit(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, acca_dvsn_cd="00")
# Out:
#   dnca_tota nxdy_excc_amt nxdy_sttl_amt nx2_day_sttl_amt
# 0         0             0             0                0

# %% [markdown]
# #### 1-23. 퇴직연금 잔고조회 [v1_국내주식-036]

# %%
##############################################################################################
# [국내주식] 주문/계좌 > 퇴직연금 잔고조회[v1_국내주식-036]
##############################################################################################
result1, result2 = ds.pension_inquire_balance(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, acca_dvsn_cd="00",
                                           inqr_dvsn="00")
print(result1)
print(result2)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []
#   dnca_tot_amt nxdy_excc_amt prvs_rcdl_excc_amt thdt_buy_amt thdt_sll_amt  \
# 0            0             0                  0            0            0
#
#   thdt_tlex_amt scts_evlu_amt tot_evlu_amt
# 0             0             0            0

# %% [markdown]
# ### **2. 기본시세**

# %% [markdown]
# #### 2-1. 주식현재가 시세 [v1_국내주식-008]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 시세[v1_국내주식-008]
##############################################################################################
ds.inquire_price(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)
# Out:
#   iscd_stat_cls_code marg_rate rprs_mrkt_kor_name new_hgpr_lwpr_cls_code  \
# 0                 55     60.00           KOSPI200                    신고가
#
#   bstp_kor_isnm temp_stop_yn oprc_rang_cont_yn clpr_rang_cont_yn crdt_able_yn  \
# 0         전기·전자            N                 N                 N            Y
#
#   grmn_rate_cls_code  ... cpfn_cnnm frgn_hldn_qty vi_cls_code  \
# 0                 60  ...   7,780 억    2977292115           N
#
#   ovtm_vi_cls_code last_ssts_cntg_qty invt_caful_yn mrkt_warn_cls_code  \
# 0                N             585046             N                 00
#
#   short_over_yn sltr_yn mang_issu_cls_code
# 0             N       N                  N
#
# [1 rows x 81 columns]

# %% [markdown]
# #### 2-2. 주식현재가 체결 [v1_국내주식-009]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 체결[v1_국내주식-009]
##############################################################################################
ds.inquire_ccnl(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)
# Out:
#    stck_cntg_hour stck_prpr prdy_vrss prdy_vrss_sign cntg_vol tday_rltv  \
# 0          155946    218000     14500              2       10    116.93
# 1          155920    218000     14500              2       30    116.93
# 2          155846    218000     14500              2        1    116.93
# 3          155749    218000     14500              2        8    116.93
# 4          155553    218000     14500              2       99    116.93
# 5          155547    218000     14500              2        6    116.93
# 6          155500    218000     14500              2        1    116.93
# 7          155459    218000     14500              2        4    116.93
# 8          155416    218000     14500              2       15    116.93
# 9          155327    218000     14500              2        4    116.93
# 10         155302    218000     14500              2        2    116.93
# 11         155218    218000     14500              2       82    116.93
# ...

# %% [markdown]
# #### 2-3. 주식현재가 일자별 [v1_국내주식-010]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 일자별[v1_국내주식-010]
##############################################################################################
ds.inquire_daily_price(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_period_div_code="D",
    fid_org_adj_prc="0"
)
# Out:
#    stck_bsop_date stck_oprc stck_hgpr stck_lwpr stck_clpr  acml_vol  \
# 0        20260226    206500    219000    206000    218000  30095763
# 1        20260225    202500    206000    201000    203500  26987996
# 2        20260224    193000    200000    192000    200000  28060617
# 3        20260223    194400    197600    190500    193000  26364684
# 4        20260220    190000    190300    188600    190100  24213880
# 5        20260219    188000    190900    187100    190000  27049388
# 6        20260213    179500    184400    178900    181200  34454192
# 7        20260212    171200    179600    170100    178600  41296011
# 8        20260211    164000    168600    162000    167800  22760242
# 9        20260210    167400    168100    165500    165800  19369566
# 10       20260209    168600    168700    165000    166400  25098971
# 11       20260206    154100    160300    151600    158600  36358081
# 12       20260205    162000    164000    158500    159300  38435228
# ...

# %% [markdown]
# #### 2-4. 주식현재가 호가/예상체결 [v1_국내주식-011]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 호가/예상체결[v1_국내주식-011]
##############################################################################################
ds.inquire_asking_price_exp_ccn(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)
# Out:
# (  aspr_acpt_hour   askp1   askp2   askp3   askp4   askp5   askp6   askp7  \
#  0         160000  218500  219000  219500  220000  220500  221000  221500
#
#      askp8   askp9  ... total_askp_rsqn total_bidp_rsqn total_askp_rsqn_icdc  \
#  0  222000  222500  ...         1145184         1077626                    0
#
#    total_bidp_rsqn_icdc ovtm_total_askp_icdc ovtm_total_bidp_icdc  \
#  0                    0                    0                    0
#
#    ovtm_total_askp_rsqn ovtm_total_bidp_rsqn ntby_aspr_rsqn new_mkop_cls_code
#  0                    0                22711         -67558                31
#
#  [1 rows x 71 columns],
#    antc_mkop_cls_code stck_prpr stck_oprc stck_hgpr stck_lwpr stck_sdpr  \
#  0                112    218000    206500    219000    206000    203500
#
#    antc_cnpr antc_cntg_vrss_sign antc_cntg_vrss antc_cntg_prdy_ctrt antc_vol  \
#  0    218000                   2          14500                7.13  2317016
#
#    stck_shrn_iscd vi_cls_code
# ...

# %% [markdown]
# #### 2-5. 주식현재가 투자자 [v1_국내주식-012]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 투자자[v1_국내주식-012]
##############################################################################################
ds.inquire_investor(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)
# Out:
#    stck_bsop_date stck_clpr prdy_vrss prdy_vrss_sign prsn_ntby_qty  \
# 0        20260226    218000     14500              2       5011907
# 1        20260225    203500      3500              2       6242239
# 2        20260224    200000      7000              2      -2406416
# 3        20260223    193000      2900              2       4154406
# 4        20260220    190100       100              2       6320615
# 5        20260219    190000      8800              2       2853975
# 6        20260213    181200      2600              2       3099928
# 7        20260212    178600     10800              2     -14428111
# 8        20260211    167800      2000              2      -4491982
# 9        20260210    165800      -600              5      -3616937
# 10       20260209    166400      7800              2      -5964986
# 11       20260206    158600      -700              5       3328122
# 12       20260205    159300     -9800              5      19450052
# ...

# %% [markdown]
# #### 2-6. 주식현재가 회원사 [v1_국내주식-013]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 회원사[v1_국내주식-013]
##############################################################################################
ds.inquire_member(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)
# Out:
#                                                    0
# 0  {'seln_mbcr_no1': '00033', 'seln_mbcr_no2': '0...

# %% [markdown]
# #### 2-7. 국내주식기간별시세(일/주/월/년) [v1_국내주식-016]

# %%
##############################################################################################
# [국내주식] 기본시세 > 국내주식기간별시세(일/주/월/년)[v1_국내주식-016]
##############################################################################################
ds.inquire_daily_itemchartprice(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_input_date_1="20250101",
    fid_input_date_2="20260226",
    fid_period_div_code="D",
    fid_org_adj_prc="0"
)
# Out:
# (  prdy_vrss prdy_vrss_sign prdy_ctrt stck_prdy_clpr  acml_vol   acml_tr_pbmn  \
#  0     14500              2      7.13         203500  30095763  6451865963088
#
#    hts_kor_isnm stck_prpr stck_shrn_iscd  prdy_vol  ... prdy_vrss_vol vol_tnrt  \
#  0         삼성전자    218000         005930  26987996  ...       3107767     0.51
#
#    stck_fcam   lstn_stcn  cpfn  hts_avls    per      eps   pbr  \
#  0       100  5919637922  7780  12904811  33.21  6564.00  3.41
#
#    itewhol_loan_rmnd_ratem name
#  0                         0.29
#
#  [1 rows x 30 columns],
#     stck_bsop_date stck_clpr stck_oprc stck_hgpr stck_lwpr  acml_vol  \
#  0        20260226    218000    206500    219000    206000  30095763
#  1        20260225    203500    202500    206000    201000  26987996
#  2        20260224    200000    193000    200000    192000  28060617
#  3        20260223    193000    194400    197600    190500  26364684
#  4        20260220    190100    190000    190300    188600  24213880
# ...

# %% [markdown]
# #### 2-8. 국내주식업종기간별시세(일_주_월_년) [v1_국내주식-021]

# %%
##############################################################################################
# [국내주식] 기본시세 > 국내주식업종기간별시세(일_주_월_년)[v1_국내주식-021]
##############################################################################################
result1, result2 = ds.inquire_daily_indexchartprice(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="0001",
    fid_input_date_1="20250101",
    fid_input_date_2="20260226",
    fid_period_div_code="D"
)
print(result1)
print(result2)
# Out:
# ERROR - API call failed: OPSQ2001 - ERROR INVALID FID_COND_MRKT_DIV_CODE
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/quotations/inquire-daily-indexchartprice
# rt_cd :  2 / msg_cd :  OPSQ2001 / msg1 :  ERROR INVALID FID_COND_MRKT_DIV_CODE
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 2-9. 주식당일분봉조회 [v1_국내주식-022]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식당일분봉조회[v1_국내주식-022]
##############################################################################################
ds.inquire_time_itemchartprice(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_input_hour_1="090000",
    fid_pw_data_incu_yn="N"
)
# Out:
# (  prdy_vrss prdy_vrss_sign prdy_ctrt stck_prdy_clpr  acml_vol   acml_tr_pbmn  \
#  0     14500              2      7.13         203500  30095763  6451865963088
#
#    hts_kor_isnm stck_prpr
#  0         삼성전자    218000  ,
#    stck_bsop_date stck_cntg_hour stck_prpr stck_oprc stck_hgpr stck_lwpr  \
#  0       20260226         090000    206500    206500    207500    206500
#
#    cntg_vol  acml_tr_pbmn
#  0  1317180  272124200500  )

# %% [markdown]
# #### 2-10. 주식현재가 당일시간대별체결 [v1_국내주식-023]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 당일시간대별체결[v1_국내주식-023]
##############################################################################################
ds.inquire_time_itemconclusion(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_input_hour_1="090000"
)
# Out:
# (  stck_prpr prdy_vrss prdy_vrss_sign prdy_ctrt  acml_vol  prdy_vol  \
#  0    218000     14500              2      7.13  30095763  26987996
#
#    rprs_mrkt_kor_name
#  0           KOSPI200  ,
#    stck_cntg_hour stck_prpr prdy_vrss prdy_vrss_sign prdy_ctrt askp bidp  \
#  0         083445    203500         0              3      0.00    0    0
#  1         083119    203500         0              3      0.00    0    0
#  2         083054    203500         0              3      0.00    0    0
#  3         083002    203500         0              3      0.00    0    0
#
#    tday_rltv acml_vol cnqn
#  0      0.00       36   20
#  1      0.00       16    1
#  2      0.00       15    5
#  3      0.00       10   10  )

# %% [markdown]
# #### 2-11. 주식현재가 시간외시간별체결 [v1_국내주식-025]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 시간외시간별체결[v1_국내주식-025]
##############################################################################################
ds.inquire_time_overtimeconclusion(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_hour_cls_code="0"
)
# Out:
# (  ovtm_untp_prpr ovtm_untp_prdy_vrss ovtm_untp_prdy_vrss_sign  \
#  0         218000                   0                        0
#
#    ovtm_untp_prdy_ctrt ovtm_untp_vol ovtm_untp_tr_pbmn ovtm_untp_mxpr  \
#  0                0.00             0                 0         239500
#
#    ovtm_untp_llam ovtm_untp_oprc ovtm_untp_hgpr ovtm_untp_lwpr  \
#  0         196500              0              0              0
#
#    ovtm_untp_antc_cnpr ovtm_untp_antc_cntg_vrss ovtm_untp_antc_cntg_vrss_sign  \
#  0                   0                        0                             3
#
#    ovtm_untp_antc_cntg_ctrt ovtm_untp_antc_vol uplm_sign lslm_sign
#  0                     0.00                  0         1         4  ,
#     stck_cntg_hour stck_prpr prdy_vrss prdy_vrss_sign prdy_ctrt    askp  \
#  0          155946    218000     14500              2      7.13  218500
#  1          155920    218000     14500              2      7.13  218500
# ...

# %% [markdown]
# #### 2-12. 주식현재가 시간외일자별주가 [v1_국내주식-026]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 시간외일자별주가[v1_국내주식-026]
##############################################################################################
ds.inquire_daily_overtimeprice(
    env_dv="real",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)
# Out:
# (  ovtm_untp_prpr ovtm_untp_prdy_vrss ovtm_untp_prdy_vrss_sign  \
#  0         218000                   0                        0
#
#    ovtm_untp_prdy_ctrt ovtm_untp_vol ovtm_untp_tr_pbmn ovtm_untp_mxpr  \
#  0                0.00             0                 0         239500
#
#    ovtm_untp_llam ovtm_untp_oprc ovtm_untp_hgpr ovtm_untp_lwpr  \
#  0         196500              0              0              0
#
#    ovtm_untp_antc_cnpr ovtm_untp_antc_cntg_vrss ovtm_untp_antc_cntg_vrss_sign  \
#  0                   0                        0                             3
#
#    ovtm_untp_antc_cntg_ctrt ovtm_untp_antc_vol
#  0                     0.00                  0  ,
#     stck_bsop_date ovtm_untp_prpr ovtm_untp_prdy_vrss ovtm_untp_prdy_vrss_sign  \
#  0        20260226         218000                   0                        0
#  1        20260225         203500                   0                        0
# ...

# %% [markdown]
# #### 2-13. 업종 분봉조회 [v1_국내주식-045]

# %%
##############################################################################################
# [국내주식] 기본시세 > 업종 분봉조회[v1_국내주식-045]
##############################################################################################
result1, result2 = ds.inquire_time_indexchartprice(
    fid_cond_mrkt_div_code="J",
    fid_etc_cls_code="0",
    fid_input_iscd="0001",
    fid_input_hour_1="090000",
    fid_pw_data_incu_yn="N"
)
print(result1)
print(result2)
# Out:
# ERROR - API call failed: OPSQ2001 - ERROR INVALID FID_COND_MRKT_DIV_CODE
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/quotations/inquire-time-indexchartprice
# rt_cd :  2 / msg_cd :  OPSQ2001 / msg1 :  ERROR INVALID FID_COND_MRKT_DIV_CODE
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 2-14. 주식현재가 시세2 [v1_국내주식-054]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식현재가 시세2[v1_국내주식-054]
##############################################################################################
ds.inquire_price_2(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)
# Out:
#   rprs_mrkt_kor_name new_hgpr_lwpr_cls_code insn_pbnt_yn stck_prpr prdy_vrss  \
# 0           KOSPI200                    신고가            N    218000     14500
#
#   prdy_vrss_sign prdy_ctrt   acml_tr_pbmn  acml_vol  prdy_vol  ...  \
# 0              2      7.13  6451865963088  30095763  26987996  ...
#
#   new_lstn_cls_name divi_app_cls_code short_over_cls_code vi_cls_code  \
# 0                                                                   N
#
#   low_current_yn ssts_hot_yn stange_runup_yn invt_caful_yn mrkt_warn_cls_code  \
# 0              N                           N             N                 00
#
#   short_over_yn
# 0             N
#
# [1 rows x 49 columns]

# %% [markdown]
# #### 2-15. 변동성완화장치(VI) 현황 [v1_국내주식-055]

# %%
##############################################################################################
# [국내주식] 기본시세 > 변동성완화장치(VI) 현황[v1_국내주식-055]
##############################################################################################
ds.inquire_vi_status(
    fid_div_cls_code="0",
    fid_cond_scr_div_code="20171",
    fid_mrkt_cls_code="K",
    fid_input_iscd="005930",
    fid_rank_sort_cls_code="0",
    fid_input_date_1="20250101",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000"
)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 2-16. 국내주식 시간외현재가 [국내주식-076]

# %%
##############################################################################################
# [국내주식] 기본시세 > 국내주식 시간외현재가[국내주식-076]
##############################################################################################
ds.inquire_overtime_price(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)
# Out:
# INFO - Data fetch complete.
#   bstp_kor_isnm ovtm_untp_prpr ovtm_untp_prdy_vrss ovtm_untp_prdy_vrss_sign  \
# 0         전기·전자         218000                   0                        0
#
#   ovtm_untp_prdy_ctrt ovtm_untp_vol ovtm_untp_tr_pbmn ovtm_untp_mxpr  \
# 0                0.00             0                 0         239500
#
#   ovtm_untp_llam ovtm_untp_oprc  ... mang_issu_yn mrkt_warn_cls_code trht_yn  \
# 0         196500              0  ...            N                 00       N
#
#   vlnt_deal_cls_name ovtm_untp_sdpr insn_pbnt_yn rprs_mrkt_kor_name  \
# 0                            218000            N           KOSPI200
#
#   ovtm_vi_cls_code    bidp    askp
# 0                N  218000  218500
#
# [1 rows x 31 columns]

# %% [markdown]
# #### 2-17. 국내주식 시간외호가 [국내주식-077]

# %%
##############################################################################################
# [국내주식] 기본시세 > 국내주식 시간외호가[국내주식-077]
##############################################################################################
ds.inquire_overtime_asking_price(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)
# Out:
#   ovtm_untp_last_hour ovtm_untp_askp1 ovtm_untp_askp2 ovtm_untp_askp3  \
# 0              180000               0               0               0
#
#   ovtm_untp_askp4 ovtm_untp_askp5 ovtm_untp_askp6 ovtm_untp_askp7  \
# 0               0               0               0               0
#
#   ovtm_untp_askp8 ovtm_untp_askp9  ... ovtm_untp_total_bidp_rsqn_icdc  \
# 0               0               0  ...                              0
#
#   ovtm_untp_ntby_bidp_rsqn total_askp_rsqn total_bidp_rsqn  \
# 0                        0         1145184         1077626
#
#   total_askp_rsqn_icdc total_bidp_rsqn_icdc ovtm_total_askp_rsqn  \
# 0                    0                    0                    0
#
#   ovtm_total_bidp_rsqn ovtm_total_askp_icdc ovtm_total_bidp_icdc
# 0                22711                    0                    0
#
# [1 rows x 60 columns]

# %% [markdown]
# #### 2-18. 국내주식 호가잔량 순위 [국내주식-089]

# %%
##############################################################################################
# [국내주식] 기본시세 > 국내주식 호가잔량 순위[국내주식-089]
##############################################################################################
ds.quote_balance(
    fid_vol_cnt="0",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_rank_sort_cls_code="0",
    fid_div_cls_code="0",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000",
    fid_input_price_1="0",
    fid_input_price_2="0"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_446754/1753406462.py in ?()
#       1 ##############################################################################################
#       2 # [국내주식] 기본시세 > 국내주식 호가잔량 순위[국내주식-089]
#       3 ##############################################################################################
# ----> 4 ds.quote_balance(
#       5     fid_vol_cnt="0",
#       6     fid_cond_mrkt_div_code="J",
#       7     fid_cond_scr_div_code="20171",
#
# ~/workspace/blsh/src/kis/domestic_stock/domestic_stock_functions.py in ?(fid_vol_cnt, fid_cond_mrkt_div_code, fid_cond_scr_div_code, fid_input_iscd, fid_rank_sort_cls_code, fid_div_cls_code, fid_trgt_cls_code, fid_trgt_exls_cls_code, fid_input_price_1, fid_input_price_2, tr_cont, dataframe)
#   13277     # 필수 파라미터 검증
#   13278     if fid_cond_mrkt_div_code != "J":
# ...

# %% [markdown]
# #### 2-19. 국내주식 시간외잔량 순위 [v1_국내주식-093]

# %%
##############################################################################################
# [국내주식] 기본시세 > 국내주식 시간외잔량 순위[v1_국내주식-093]
##############################################################################################
ds.after_hour_balance(
    fid_input_price_1="0",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_rank_sort_cls_code="0",
    fid_div_cls_code="0",
    fid_input_iscd="005930",
    fid_trgt_exls_cls_code="0000000000",
    fid_trgt_cls_code="111111111",
    fid_vol_cnt="0",
    fid_input_price_2="0"
)

# %% [markdown]
# #### 2-20. 국내주식 장마감 예상체결가 [국내주식-120]

# %%
##############################################################################################
# [국내주식] 기본시세 > 국내주식 장마감 예상체결가[국내주식-120]
##############################################################################################
ds.exp_closing_price(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_rank_sort_cls_code="0",
    fid_cond_scr_div_code="20171",
    fid_blng_cls_code="0"
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 2-21. 회원사 실시간 매매동향(틱) [국내주식-163]

# %%
##############################################################################################
# [국내주식] 기본시세 > 회원사 실 시간 매매동향(틱)[국내주식-163]
##############################################################################################
result1, result2 = ds.frgnmem_trade_trend(
    fid_cond_scr_div_code="20171",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_input_iscd_2="00030",
    fid_mrkt_cls_code="K",
    fid_vol_cnt="0"
)
print(result1)
print(result2)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []
#    bsop_hour mbcr_name hts_kor_isnm stck_prpr prdy_vrss prdy_vrss_sign  \
# 0     153230      삼성증권      영원무역홀딩스    245000     -5000              5
# 1     153136      삼성증권         태양금속      3025       -25              5
# 2     153136      삼성증권       롯데정밀화학     50900      -500              5
# 3     153135      삼성증권     한진중공업홀딩스      5190      -110              5
# 4     153135      삼성증권        대한항공우     24900      -550              5
# ..       ...       ...          ...       ...       ...            ...
# 95    153112      삼성증권         조선선재    110800      2600              2
# 96    153112      삼성증권          GKL     13270      -360              5
# 97    153112      삼성증권         영원무역     93000      1000              2
# 98    153111      삼성증권         이연제약     11140      -230              5
# 99    153111      삼성증권        인바이오젠      9830      -210              5
#
# ...

# %% [markdown]
# #### 2-22. 주식일별분봉조회 [국내주식-213]

# %%
##############################################################################################
# [국내주식] 기본시세 > 주식일별분봉조회 [국내주식-213]
##############################################################################################
ds.inquire_time_dailychartprice(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_input_hour_1="090000",
    fid_input_date_1="20260226"
)
# Out:
# (  prdy_vrss prdy_vrss_sign prdy_ctrt stck_prdy_clpr  acml_vol   acml_tr_pbmn  \
#  0     14500              2      7.13         203500  30095763  6451865963088
#
#    hts_kor_isnm stck_prpr
#  0         삼성전자    218000  ,
#    stck_bsop_date stck_cntg_hour stck_prpr stck_oprc stck_hgpr stck_lwpr  \
#  0       20260226         090000    206500    206500    207500    206500
#
#    cntg_vol  acml_tr_pbmn
#  0  1317180  272124200500  )

# %% [markdown]
# ### **3. ELW 시세**

# %% [markdown]
# #### 3-1. ELW 현재가 시세 [v1_국내주식-014]

# %%
##############################################################################################
# [국내주식] ELW시세 > ELW 현재가 시세 [v1_국내주식-014]
##############################################################################################
ds.inquire_elw_price(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)

# %% [markdown]
# ### **4. 업종/기타**

# %% [markdown]
# #### 4-1. 국내휴장일조회 [국내주식-040]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 국내휴장일조회[국내주식-040]
##############################################################################################
ds.chk_holiday(bass_dt="20260226")
# Out:
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# INFO - Call Next page...
# WARNING - Max recursive depth reached.
#       bass_dt wday_dvsn_cd bzdy_yn tr_day_yn opnd_yn sttl_day_yn
# 0    20260226           05       Y         Y       Y           Y
# 1    20260227           06       Y         Y       Y           Y
# 2    20260228           07       N         Y       N           N
# 3    20260301           01       N         Y       N           N
# 4    20260302           02       N         Y       N           N
# ..        ...          ...     ...       ...     ...         ...
# 259  20261112           05       Y         Y       Y           Y
# 260  20261113           06       Y         Y       Y           Y
# ...

# %% [markdown]
# #### 4-2. 국내업종 현재지수 [v1_국내주식-063]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 국내업종 현재지수 [v1_국내주식-063]
##############################################################################################
ds.inquire_index_price(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="0001"
)
# Out:
# INFO - Data fetch complete.
#   bstp_nmix_prpr bstp_nmix_prdy_vrss bstp_nmix_prdy_ctrt acml_vol prdy_vol  \
# 0              0                   0                0.00        0        0
#
#   acml_tr_pbmn prdy_tr_pbmn bstp_nmix_oprc prdy_nmix_vrss_nmix_oprc  \
# 0            0            0              0                        0
#
#   oprc_vrss_prpr_sign  ... stnr_issu_cnt down_issu_cnt lslm_issu_cnt  \
# 0                   3  ...             0             0             0
#
#   dryy_hgpr_vrss_prpr_rate dryy_lwpr_vrss_prpr_rate total_askp_rsqn  \
# 0                     0.00                     0.00               0
#
#   total_bidp_rsqn seln_rsqn_rate shnu_rsqn_rate ntby_rsqn
# 0               0           0.00           0.00         0
#
# [1 rows x 31 columns]

# %% [markdown]
# #### 4-3. 국내업종 시간별지수(초) [국내주식-064]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 국내업종 시간별지수(초)[국내주식-064]
##############################################################################################
ds.inquire_index_tickprice(
    fid_input_iscd="0001",
    fid_cond_mrkt_div_code="J"
)

# %% [markdown]
# #### 4-4. 국내업종 일자별지수 [v1_국내주식-065]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 국내업종 일자별지수 [v1_국내주식-065]
##############################################################################################
result1, result2 = ds.inquire_index_daily_price(
    fid_period_div_code="D",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="0001",
    fid_input_date_1="20260226"
)
print(result1)
print(result2)
# Out:
# ERROR - API call failed: OPSQ2001 - ERROR INVALID FID_COND_MRKT_DIV_CODE
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/quotations/inquire-index-daily-price
# rt_cd :  2 / msg_cd :  OPSQ2001 / msg1 :  ERROR INVALID FID_COND_MRKT_DIV_CODE
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 4-5. 국내업종 구분별전체시세 [v1_국내주식-066]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 국내업종 구분별전체시세[v1_국내주식-066]
##############################################################################################
result1, result2 = ds.inquire_index_category_price(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="0001",
    fid_cond_scr_div_code="20171",
    fid_mrkt_cls_code="K",
    fid_blng_cls_code="0"
)
print(result1)
print(result2)
# Out:
# ERROR - API call failed: OPSQ2001 - ERROR INVALID FID_COND_MRKT_DIV_CODE
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/quotations/inquire-index-category-price
# rt_cd :  2 / msg_cd :  OPSQ2001 / msg1 :  ERROR INVALID FID_COND_MRKT_DIV_CODE
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 4-6. 국내업종 시간별지수(분) [국내주식-119]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 국내업종 시간별지수(분)[국내주식-119]
##############################################################################################
ds.inquire_index_timeprice(
    fid_input_hour_1="090000",
    fid_input_iscd="0001",
    fid_cond_mrkt_div_code="J"
)

# %% [markdown]
# #### 4-7. 국내주식 예상체결지수 추이 [국내주식-121]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 국내주식 예상체결지수 추이[국내주식-121]
##############################################################################################
ds.exp_index_trend(
    fid_mkop_cls_code="0",
    fid_input_hour_1="090000",
    fid_input_iscd="0001",
    fid_cond_mrkt_div_code="J"
)

# %% [markdown]
# #### 4-8. 국내주식 예상체결 전체지수 [국내주식-122]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 국내주식 예상체결 전체지수[국내주식-122]
##############################################################################################
result1, result2 = ds.exp_total_index(
    fid_mrkt_cls_code="K",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="0001",
    fid_mkop_cls_code="0"
)
print(result1)
print(result2)

# %% [markdown]
# #### 4-9. 금리 종합(국내채권_금리) [국내주식-155]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 금리 종합(국내채권_금리)[국내주식-155]
##############################################################################################
result1, result2 = ds.comp_interest(
    fid_cond_mrkt_div_code="B",
    fid_cond_scr_div_code="20156",
    fid_div_cls_code="0",
    fid_div_cls_code1="0"
)
print(result1)
print(result2)

# %% [markdown]
# #### 4-10. 국내선물 영업일조회 [국내주식-160]

# %%
##############################################################################################
# [국내주식] 업종/기타 > 국내선물 영업일조회 [국내주식-160]
##############################################################################################
ds.market_time()

# %% [markdown]
# ### **5. 종목정보**

# %% [markdown]
# #### 5-1. 상품기본조회 [v1_국내주식-029]

# %%
##############################################################################################
# [국내주식] 종목정보 > 상품기본조회[v1_국내주식-029]
##############################################################################################
ds.search_info(
    pdno="005930",
    prdt_type_cd="300"
)
# Out:
# INFO - Data fetch complete.
#            pdno prdt_type_cd prdt_name prdt_name120 prdt_abrv_name  \
# 0  00000A005930          300   삼성전자보통주      삼성전자보통주           삼성전자
#
#         prdt_eng_name    prdt_eng_name120 prdt_eng_abrv_name      std_pdno  \
# 0  SamsungElectronics  SamsungElectronics        SamsungElec  KR7005930003
#
#   shtn_pdno prdt_sale_stat_cd prdt_risk_grad_cd prdt_clsf_cd prdt_clsf_name  \
# 0    005930                                           101010             주권
#
#   sale_strt_dt sale_end_dt wrap_asst_type_cd ivst_prdt_type_cd  \
# 0                                         01              1010
#
#   ivst_prdt_type_cd_name frst_erlm_dt
# 0                     주식

# %% [markdown]
# #### 5-2. 주식기본조회 [v1_국내주식-067]

# %%
##############################################################################################
# [국내주식] 종목정보 > 주식기본조회[v1_국내주식-067]
##############################################################################################
ds.search_stock_info(
    prdt_type_cd="300",
    pdno="005930"
)

# %% [markdown]
# #### 5-3. 국내주식 대차대조표 [v1_국내주식-078]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 대차대조표 [v1_국내주식-078]
##############################################################################################
ds.finance_balance_sheet(
    fid_div_cls_code="0",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)

# %% [markdown]
# #### 5-4. 국내주식 손익계산서 [v1_국내주식-079]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 손익계산서 [v1_국내주식-079]
##############################################################################################
ds.finance_income_statement(
    fid_div_cls_code="0",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)

# %% [markdown]
# #### 5-5. 국내주식 재무비율 [v1_국내주식-080]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 재무비율 [v1_국내주식-080]
##############################################################################################
ds.finance_financial_ratio(
    fid_div_cls_code="0",
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)

# %% [markdown]
# #### 5-6. 국내주식 수익성비율 [v1_국내주식-081]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 수익성비율[v1_국내주식-081]
##############################################################################################
ds.finance_profit_ratio(
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_cond_mrkt_div_code="J"
)

# %% [markdown]
# #### 5-7. 국내주식 기타주요비율 [v1_국내주식-082]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 기타주요비율[v1_국내주식-082]
##############################################################################################
ds.finance_other_major_ratios(
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_cond_mrkt_div_code="J"
)

# %% [markdown]
# #### 5-8. 국내주식 안정성비율 [v1_국내주식-083]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 안정성비율[v1_국내주식-083]
##############################################################################################
ds.finance_stability_ratio(
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_cond_mrkt_div_code="J"
)

# %% [markdown]
# #### 5-9. 국내주식 성장성비율 [v1_국내주식-085]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 성장성비율 [v1_국내주식-085]
##############################################################################################
ds.finance_growth_ratio(
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_cond_mrkt_div_code="J"
)

# %% [markdown]
# #### 5-10. 국내주식 당사 신용가능종목 [국내주식-111]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 당사 신용가능종목[국내주식-111]
##############################################################################################
ds.credit_by_company(
    fid_rank_sort_cls_code="0",
    fid_slct_yn="Y",
    fid_input_iscd="005930",
    fid_cond_scr_div_code="20171",
    fid_cond_mrkt_div_code="J"
)

# %% [markdown]
# #### 5-11. 종합 시황/공시(제목) [국내주식-141]

# %%
##############################################################################################
# [국내주식] 종목정보 > 종합 시황/공시(제목) [국내주식-141]
##############################################################################################
ds.news_title(
    fid_news_ofer_entp_code="",
    fid_cond_mrkt_cls_code="K",
    fid_input_iscd="005930",
    fid_titl_cntt="",
    fid_input_date_1="20250101",
    fid_input_hour_1="090000",
    fid_rank_sort_cls_code="0",
    fid_input_srno="0"
)

# %% [markdown]
# #### 5-12. 예탁원정보(유상증자일정) [국내주식-143]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(유상증자일정)[국내주식-143]
##############################################################################################
ds.ksdinfo_paidin_capin(
    cts="",
    gb1="0",
    f_dt="20250101",
    t_dt="20260226",
    sht_cd="005930"
)

# %% [markdown]
# #### 5-13. 예탁원정보(무상증자일정) [국내주식-144]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(무상증자일정)[국내주식-144]
##############################################################################################
ds.ksdinfo_bonus_issue(
    cts="",
    f_dt="20250101",
    t_dt="20260226",
    sht_cd="005930"
)

# %% [markdown]
# #### 5-14. 예탁원정보(배당일정) [국내주식-145]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(배당일정)[국내주식-145]
##############################################################################################
ds.ksdinfo_dividend(
    cts="",
    gb1="0",
    f_dt="20250101",
    t_dt="20260226",
    sht_cd="005930",
    high_gb="0"
)

# %% [markdown]
# #### 5-15. 예탁원정보(주식매수청구일정) [국내주식-146]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(주식매수청구일정)[국내주식-146]
##############################################################################################
ds.ksdinfo_purreq(
    sht_cd="005930",
    t_dt="20260226",
    f_dt="20250101",
    cts=""
)

# %% [markdown]
# #### 5-16. 예탁원정보(합병_분할일정) [국내주식-147]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(합병_분할일정)[국내주식-147]
##############################################################################################
ds.ksdinfo_merger_split(
    cts="",
    f_dt="20250101",
    t_dt="20260226",
    sht_cd="005930"
)

# %% [markdown]
# #### 5-17. 예탁원정보(액면교체일정) [국내주식-148]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(액면교체일정)[국내주식-148]
##############################################################################################
ds.ksdinfo_rev_split(
    sht_cd="005930",
    cts="",
    f_dt="20250101",
    t_dt="20260226",
    market_gb="K"
)

# %% [markdown]
# #### 5-18. 예탁원정보(자본감소일정) [국내주식-149]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(자본감소일정) [국내주식-149]
##############################################################################################
ds.ksdinfo_cap_dcrs(
    cts="",
    f_dt="20250101",
    t_dt="20260226",
    sht_cd="005930"
)

# %% [markdown]
# #### 5-19. 예탁원정보(상장정보일정) [국내주식-150]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(상장정보일정)[국내주식-150]
##############################################################################################
ds.ksdinfo_list_info(
    sht_cd="005930",
    t_dt="20260226",
    f_dt="20250101",
    cts=""
)

# %% [markdown]
# #### 5-20. 예탁원정보(공모주청약일정) [국내주식-151]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(공모주청약일정)[국내주식-151]
##############################################################################################
ds.ksdinfo_pub_offer(
    sht_cd="005930",
    cts="",
    f_dt="20250101",
    t_dt="20260226"
)

# %% [markdown]
# #### 5-21. 예탁원정보(실권주일정) [국내주식-152]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(실권주일정)[국내주식-152]
##############################################################################################
ds.ksdinfo_forfeit(
    sht_cd="005930",
    t_dt="20260226",
    f_dt="20250101",
    cts=""
)

# %% [markdown]
# #### 5-22. 예탁원정보(의무예치일정) [국내주식-153]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(의무예치일정) [국내주식-153]
##############################################################################################
ds.ksdinfo_mand_deposit(
    t_dt="20260226",
    sht_cd="005930",
    f_dt="20250101",
    cts=""
)

# %% [markdown]
# #### 5-23. 예탁원정보(주주총회일정) [국내주식-154]

# %%
##############################################################################################
# [국내주식] 종목정보 > 예탁원정보(주주총회일정)[국내주식-154]
##############################################################################################
ds.ksdinfo_sharehld_meet(
    cts="",
    f_dt="20250101",
    t_dt="20260226",
    sht_cd="005930"
)

# %% [markdown]
# #### 5-24. 국내주식 종목추정실적 [국내주식-187]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 종목추정실적[국내주식-187]
##############################################################################################
result1, result2 = ds.estimate_perform(
    sht_cd="005930"
)
print(result1)
print(result2)

# %% [markdown]
# #### 5-25. 국내주식 종목투자의견 [국내주식-188]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 종목투자의견[국내주식-188]
##############################################################################################
ds.invest_opinion(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_input_date_1="20250101",
    fid_input_date_2="20260226"
)

# %% [markdown]
# #### 5-26. 국내주식 증권사별 투자의견 [국내주식-189]

# %%
##############################################################################################
# [국내주식] 종목정보 > 국내주식 증권사별 투자의견[국내주식-189]
##############################################################################################
ds.invest_opbysec(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_input_date_1="20250101",
    fid_input_date_2="20260226"
)
# Out:
# INFO - Data fetch complete.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 5-27. 당사 대주가능 종목 [국내주식-195]

# %%
##############################################################################################
# [국내주식] 종목정보 > 당사 대주가능 종목 [국내주식-195]
##############################################################################################
result1, result2 = ds.lendable_by_company(excg_dvsn_cd="00", pdno="", thco_stln_psbl_yn="Y", inqr_dvsn_1="0", ctx_area_fk200="",
                               ctx_area_nk100="")
print(result1)
print(result2)
# Out:
# INFO - Calling next page...
# ERROR - API call failed: SYDB0050 - 조회이후에 자료가 변경되었습니다.(다시 조회하세요)
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/quotations/lendable-by-company
# rt_cd :  7 / msg_cd :  SYDB0050 / msg1 :  조회이후에 자료가 변경되었습니다.(다시 조회하세요)
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### **6. 시세분석**

# %% [markdown]
# #### 6-1. 국내기관_외국인 매매종목가집계 [국내주식-037]

# %%
##############################################################################################
# [국내주식] 시세분석 > 국내기관_외국인 매매종목가집계[국내주식-037]
##############################################################################################
ds.foreign_institution_total(
    fid_cond_mrkt_div_code="V",
    fid_cond_scr_div_code="16449",
    fid_input_iscd="0000",
    fid_div_cls_code="0",
    fid_rank_sort_cls_code="0",
    fid_etc_cls_code="0"
)
# Out:
# INFO - Data fetch complete.
#    hts_kor_isnm mksc_shrn_iscd ntby_qty stck_prpr prdy_vrss_sign prdy_vrss  \
# 0          대우건설         047040  2001000     10140              2        90
# 1           카카오         035720  1909000     62300              2       900
# 2         삼성중공업         010140  1470000     28950              2       250
# 3         신성이엔지         011930  1452000      2450              2       315
# 4          현대제철         004020  1281000     46500              2      7700
# 5        아주IB투자         027360  1036000      5810              1      1340
# 6        이수페타시스         007660   892000    127600              2      9100
# 7       두산에너빌리티         034020   883000    106300              2      2500
# 8        미래에셋증권         006800   866000     72000              5     -1600
# 9           팬오션         028670   846000      5280              5       -20
# 10         현대로템         064350   792000    230500              2     10500
# ...

# %% [markdown]
# #### 6-2. 종목조건검색 목록조회 [국내주식-038]

# %%
##############################################################################################
# [국내주식] 시세분석 > 종목조건검색 목록조회[국내주식-038]
##############################################################################################
ds.psearch_title(user_id=trenv.my_htsid)
# Out:
# -------------------------------
# Error in response:  200  url= /uapi/domestic-stock/v1/quotations/psearch-title
# rt_cd :  1 / msg_cd :  MCA05762 / msg1 :  조회가 계속 됩니다. (다음을 누르십시오.)
# -------------------------------
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 6-3. 종목조건검색조회 [국내주식-039]

# %%
##############################################################################################
# [국내주식] 시세분석 > 종목조건검색조회 [국내주식-039]
##############################################################################################
ds.psearch_result(
    user_id=trenv.my_id,
    seq="1"
)

# %% [markdown]
# #### 6-4. 종목별 프로그램매매추이(체결) [v1_국내주식-044]

# %%
##############################################################################################
# [국내주식] 시세분석 > 종목별 프로그램매매추이(체결)[v1_국내주식-044]
##############################################################################################
ds.program_trade_by_stock(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)

# %% [markdown]
# #### 6-5. 종목별 외인기관 추정가집계 [v1_국내주식-046]

# %%
##############################################################################################
# [국내주식] 시세분석 > 종목별 외인기관 추정가집계[v1_국내주식-046]
##############################################################################################
ds.investor_trend_estimate(
    mksc_shrn_iscd="005930"
)

# %% [markdown]
# #### 6-6. 종목별일별매수매도체결량 [v1_국내주식-056]

# %%
##############################################################################################
# [국내주식] 시세분석 > 종목별일별매수매도체결량 [v1_국내주식-056]
##############################################################################################
ds.inquire_daily_trade_volume(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_period_div_code="D"
)

# %% [markdown]
# #### 6-7. 시장별 투자자매매동향(시세) [v1_국내주식-074]

# %%
##############################################################################################
# [국내주식] 시세분석 > 시장별 투자자매매동향(시세)[v1_국내주식-074]
##############################################################################################
ds.inquire_investor_time_by_market(
    fid_input_iscd="0001",
    fid_input_iscd_2="0002"
)

# %% [markdown]
# #### 6-8. 시장별 투자자매매동향(일별) [국내주식-075]

# %%
##############################################################################################
# [국내주식] 시세분석 > 시장별 투자자매매동향(일별) [국내주식-075]
##############################################################################################
ds.inquire_investor_daily_by_market(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="0001",
    fid_input_date_1="20250101",
    fid_input_iscd_1="0001",
    fid_input_date_2="20260226",
    fid_input_iscd_2="0002"
)

# %% [markdown]
# #### 6-9. 국내주식 신용잔고 일별추이 [국내주식-110]

# %%
##############################################################################################
# [국내주식] 시세분석 > 국내주식 신용잔고 일별추이[국내주식-110]
##############################################################################################
ds.daily_credit_balance(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_input_date_1="20250101"
)

# %% [markdown]
# #### 6-10. 종목별 프로그램매매추이(일별) [국내주식-113]

# %%
##############################################################################################
# [국내주식] 시세분석 > 종목별 프로그램매매추이(일별) [국내주식-113]
##############################################################################################
ds.program_trade_by_stock_daily(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)

# %% [markdown]
# #### 6-11. 프로그램매매 종합현황(시간) [국내주식-114]

# %%
##############################################################################################
# [국내주식] 시세분석 > 프로그램매매 종합현황(시간) [국내주식-114]
##############################################################################################
ds.comp_program_trade_today(
    fid_cond_mrkt_div_code="J",
    fid_mrkt_cls_code="K"
)

# %% [markdown]
# #### 6-12. 프로그램매매 종합현황(일별) [국내주식-115]

# %%
##############################################################################################
# [국내주식] 시세분석 > 프로그램매매 종합현황(일별)[국내주식-115]
##############################################################################################
ds.comp_program_trade_daily(
    fid_cond_mrkt_div_code="J",
    fid_mrkt_cls_code="K"
)

# %% [markdown]
# #### 6-13. 프로그램매매 투자자매매동향(당일) [국내주식-116]

# %%
##############################################################################################
# [국내주식] 시세분석 > 프로그램매매 투자자매매동향(당일) [국내주식-116]
##############################################################################################
ds.investor_program_trade_today(
    mrkt_div_cls_code="K"
)

# %% [markdown]
# #### 6-14. 국내주식 예상체결가 추이 [국내주식-118]

# %%
##############################################################################################
# [국내주식] 시세분석 > 국내주식 예상체결가 추이[국내주식-118]
##############################################################################################
ds.exp_price_trend(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_mkop_cls_code="0"
)

# %% [markdown]
# #### 6-15. 국내주식 공매도 일별추이 [국내주식-134]

# %%
##############################################################################################
# [국내주식] 시세분석 > 국내주식 공매도 일별추이[국내주식-134]
##############################################################################################
ds.daily_short_sale(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930"
)

# %% [markdown]
# #### 6-16. 종목별 일별 대차거래추이 [국내주식-135]

# %%
##############################################################################################
# [국내주식] 시세분석 > 종목별 일별 대차거래추이 [국내주식-135]
##############################################################################################
ds.daily_loan_trans(
    mrkt_div_cls_code="K",
    mksc_shrn_iscd="005930"
)

# %% [markdown]
# #### 6-17. 국내주식 시간외거래량순위 [국내주식-139]

# %%
##############################################################################################
# [국내주식] 국내주식 > 국내주식 시간외거래량순위[국내주식-139]
##############################################################################################
result1, result2 = ds.overtime_volume(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_rank_sort_cls_code="0",
    fid_input_price_1="0",
    fid_input_price_2="0",
    fid_vol_cnt="0",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000"
)
print(result1)
print(result2)

# %% [markdown]
# #### 6-18. 국내주식 시간외예상체결등락률 [국내주식-140]

# %%
##############################################################################################
# [국내주식] 시세분석 > 국내주식 시간외예상체결등락률 [국내주식-140]
##############################################################################################
ds.overtime_exp_trans_fluct(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_rank_sort_cls_code="0",
    fid_div_cls_code="0"
)

# %% [markdown]
# #### 6-19. 외국계 매매종목 가집계 [국내주식-161]

# %%
##############################################################################################
# [국내주식] 시세분석 > 외국계 매매종목 가집계 [국내주식-161]
##############################################################################################
ds.frgnmem_trade_estimate(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_rank_sort_cls_code="0",
    fid_rank_sort_cls_code_2="0"
)

# %% [markdown]
# #### 6-20. 종목별 외국계 순매수추이 [국내주식-164]

# %%
##############################################################################################
# [국내주식] 시세분석 > 종목별 외국계 순매수추이 [국내주식-164]
##############################################################################################
ds.frgnmem_pchs_trend(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_input_iscd_2="00030"
)

# %% [markdown]
# #### 6-21. 국내주식 상하한가 포착 [국내주식-190]

# %%
##############################################################################################
# [국내주식] 시세분석 > 국내주식 상하한가 포착 [국내주식-190]
##############################################################################################
ds.capture_uplowprice(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_prc_cls_code="0",
    fid_div_cls_code="0",
    fid_input_iscd="005930"
)

# %% [markdown]
# #### 6-22. 국내주식 체결금액별 매매비중 [국내주식-192]

# %%
##############################################################################################
# [국내주식] 시세분석 > 국내주식 체결금액별 매매비중 [국내주식-192]
##############################################################################################
ds.tradprt_byamt(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930"
)

# %% [markdown]
# #### 6-23. 국내 증시자금 종합 [국내주식-193]

# %%
##############################################################################################
# [국내주식] 시세분석 > 국내 증시자금 종합 [국내주식-193]
##############################################################################################
ds.mktfunds()

# %% [markdown]
# #### 6-24. 국내주식 매물대/거래비중 [국내주식-196]

# %%
##############################################################################################
# [국내주식] 시세분석 > 국내주식 매물대/거래비중 [국내주식-196]
##############################################################################################
ds.pbar_tratio(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_cond_scr_div_code="20171"
)

# %% [markdown]
# #### 6-25. 주식현재가 회원사 종목매매동향 [국내주식-197]

# %%
##############################################################################################
# [국내주식] 시세분석 > 주식현재가 회원사 종목매매동향 [국내주식-197]
##############################################################################################
ds.inquire_member_daily(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_input_iscd_2="00030",
    fid_input_date_1="20250101",
    fid_input_date_2="20260226"
)

# %% [markdown]
# #### 6-26. 관심종목 그룹별 종목조회 [국내주식-203]

# %%
##############################################################################################
# [국내주식] 시세분석 > 관심종목 그룹별 종목조회 [국내주식-203]
##############################################################################################
result1, result2 = ds.intstock_stocklist_by_group(
    type="1",
    user_id=trenv.my_htsid,
    inter_grp_code="001",
    fid_etc_cls_code="4"
)
print(result1)
print(result2)

# %% [markdown]
# #### 6-27. 관심종목 그룹조회 [국내주식-204]

# %%
##############################################################################################
# [국내주식] 시세분석 > 관심종목 그룹조회 [국내주식-204]
##############################################################################################
ds.intstock_grouplist(
    type="1",
    fid_etc_cls_code="0",
    user_id=trenv.my_id
)

# %% [markdown]
# #### 6-28. 관심종목(멀티종목) 시세조회 [국내주식-205]

# %%
##############################################################################################
# [국내주식] 시세분석 > 관심종목(멀티종목) 시세조회 [국내주식-205]
##############################################################################################
ds.intstock_multprice(
    fid_cond_mrkt_div_code_1="J",
    fid_input_iscd_1="419530",
    fid_cond_mrkt_div_code_2="J",
    fid_input_iscd_2="092070"
)
# Out:
# INFO - Data fetch complete.
#   kospi_kosdaq_cls_name mrkt_trtm_cls_name hour_cls_code inter_shrn_iscd  \
# 0                                                      0          419530
# 1                                                      0          092070
#
#   inter_kor_isnm inter2_prpr inter2_prdy_vrss prdy_vrss_sign prdy_ctrt  \
# 0         SAMG엔터       35150             -650              5     -1.82
# 1           디엔에프       22100             -700              5     -3.07
#
#   acml_vol  ... total_askp_rsqn total_bidp_rsqn acml_tr_pbmn inter2_prdy_clpr  \
# 0    85512  ...            1670            7396   2999238350            35800
# 1   170809  ...            5051           13075   3755956950            22800
#
#   oprc_vrss_hgpr_rate intr_antc_cntg_vrss intr_antc_cntg_vrss_sign  \
# 0                0.00                   0                        3
# 1                1.10                   0                        3
#
#   intr_antc_cntg_prdy_ctrt intr_antc_vol inter2_sdpr
# ...

# %% [markdown]
# #### 6-29. 종목별 투자자매매동향(일별) [종목별 투자자매매동향(일별)]

# %%
##############################################################################################
# [국내주식] 시세분석  > 종목별 투자자매매동향(일별)[종목별 투자자매매동향(일별)]
##############################################################################################
result1, result2 = ds.investor_trade_by_stock_daily(
    fid_cond_mrkt_div_code="J",
    fid_input_iscd="005930",
    fid_input_date_1="20250101",
    fid_org_adj_prc="0",
    fid_etc_cls_code="0"
)
print(result1)
print(result2)

# %% [markdown]
# ### **7. 순위분석**

# %% [markdown]
# #### 7-1. 거래량순위 [v1_국내주식-047]

# %%
##############################################################################################
# [국내주식] 순위분석 > 거래량순위[v1_국내주식-047]
##############################################################################################
ds.volume_rank(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_blng_cls_code="0",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000",
    fid_input_price_1="0",
    fid_input_price_2="0",
    fid_vol_cnt="0",
    fid_input_date_1="20260226"
)
# Out:
# The End
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 7-2. 등락률 순위 [v1_국내주식-088]

# %%
##############################################################################################
# [국내주식] 순위분석 > 등락률 순위[v1_국내주식-088]
##############################################################################################
ds.fluctuation(
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_rank_sort_cls_code="0",
    fid_input_cnt_1="0",
    fid_prc_cls_code="0",
    fid_input_price_1="0",
    fid_input_price_2="0",
    fid_vol_cnt="0",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000",
    fid_div_cls_code="0",
    fid_rsfl_rate1="0",
    fid_rsfl_rate2="0"
)

# %% [markdown]
# #### 7-3. 국내주식 수익자산지표 순위 [v1_국내주식-090]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 수익자산지표 순위[v1_국내주식-090]
##############################################################################################
ds.profit_asset_index(
    fid_cond_mrkt_div_code="J",
    fid_trgt_cls_code="111111111",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_input_price_1="0",
    fid_input_price_2="0",
    fid_vol_cnt="0",
    fid_input_option_1="0",
    fid_input_option_2="0",
    fid_rank_sort_cls_code="0",
    fid_blng_cls_code="0",
    fid_trgt_exls_cls_code="0000000000"
)

# %% [markdown]
# #### 7-4. 국내주식 시가총액 상위 [v1_국내주식-091]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 시가총액 상위 [v1_국내주식-091]
##############################################################################################
ds.market_cap(
    fid_input_price_2="0",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_div_cls_code="0",
    fid_input_iscd="005930",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000",
    fid_input_price_1="0",
    fid_vol_cnt="0"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_443886/1461078682.py in ?()
#       1 ##############################################################################################
#       2 # [국내주식] 순위분석 > 국내주식 시가총액 상위 [v1_국내주식-091]
#       3 ##############################################################################################
# ----> 4 ds.market_cap(
#       5     fid_input_price_2="0",
#       6     fid_cond_mrkt_div_code="J",
#       7     fid_cond_scr_div_code="20171",
#
# ~/workspace/blsh/src/kis/domestic_stock/domestic_stock_functions.py in ?(fid_input_price_2, fid_cond_mrkt_div_code, fid_cond_scr_div_code, fid_div_cls_code, fid_input_iscd, fid_trgt_cls_code, fid_trgt_exls_cls_code, fid_input_price_1, fid_vol_cnt, tr_cont, dataframe)
#   10200     # 필수 파라미터 검증
#   10201     if fid_cond_mrkt_div_code != "J":
# ...

# %% [markdown]
# #### 7-5. 국내주식 재무비율 순위 [v1_국내주식-092]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 재무비율 순위[v1_국내주식-092]
##############################################################################################
ds.finance_ratio(
    fid_trgt_cls_code="111111111",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_input_price_1="0",
    fid_input_price_2="0",
    fid_vol_cnt="0",
    fid_input_option_1="0",
    fid_input_option_2="0",
    fid_rank_sort_cls_code="0",
    fid_blng_cls_code="0",
    fid_trgt_exls_cls_code="0000000000"
)

# %% [markdown]
# #### 7-6. 국내주식 우선주_괴리율 상위 [v1_국내주식-094]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 우선주_괴리율 상위[v1_국내주식-094]
##############################################################################################
ds.prefer_disparate_ratio(
    fid_vol_cnt="0",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_div_cls_code="0",
    fid_input_iscd="005930",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000",
    fid_input_price_1="0",
    fid_input_price_2="0"
)

# %% [markdown]
# #### 7-7. 국내주식 이격도 순위 [v1_국내주식-095]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 이격도 순위 [v1_국내주식-095]
##############################################################################################
ds.disparity(
    fid_input_price_2="0",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_div_cls_code="0",
    fid_rank_sort_cls_code="0",
    fid_hour_cls_code="0",
    fid_input_iscd="005930",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000",
    fid_input_price_1="0",
    fid_vol_cnt="0"
)

# %% [markdown]
# #### 7-8. 국내주식 시장가치 순위 [v1_국내주식-096]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 시장가치 순위[v1_국내주식-096]
##############################################################################################
ds.market_value(
    fid_trgt_cls_code="111111111",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_input_price_1="0",
    fid_input_price_2="0",
    fid_vol_cnt="0",
    fid_input_option_1="0",
    fid_input_option_2="0",
    fid_rank_sort_cls_code="0",
    fid_blng_cls_code="0",
    fid_trgt_exls_cls_code="0000000000"
)

# %% [markdown]
# #### 7-9. 국내주식 체결강도 상위 [v1_국내주식-101]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 체결강도 상위[v1_국내주식-101]
##############################################################################################
ds.volume_power(
    fid_trgt_exls_cls_code="0000000000",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_input_price_1="0",
    fid_input_price_2="0",
    fid_vol_cnt="0",
    fid_trgt_cls_code="111111111"
)

# %% [markdown]
# #### 7-10. 국내주식 관심종목등록 상위 [v1_국내주식-102]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 관심종목등록 상위[v1_국내주식-102]
##############################################################################################
ds.top_interest_stock(
    fid_input_iscd_2="000000",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000",
    fid_input_price_1="0",
    fid_input_price_2="0",
    fid_vol_cnt="0",
    fid_div_cls_code="0",
    fid_input_cnt_1="0"
)

# %% [markdown]
# #### 7-11. 국내주식 예상체결 상승_하락상위 [v1_국내주식-103]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 예상체결 상승_하락상위[v1_국내주식-103]
##############################################################################################
ds.exp_trans_updown(
    fid_rank_sort_cls_code="0",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_aply_rang_prc_1="0",
    fid_vol_cnt="0",
    fid_pbmn="0",
    fid_blng_cls_code="0",
    fid_mkop_cls_code="0"
)

# %% [markdown]
# #### 7-12. 국내주식 당사매매종목 상위 [v1_국내주식-104]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 당사매매종목 상위[v1_국내주식-104]
##############################################################################################
ds.traded_by_company(
    fid_trgt_exls_cls_code="0000000000",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_div_cls_code="0",
    fid_rank_sort_cls_code="0",
    fid_input_date_1="20250101",
    fid_input_date_2="20260226",
    fid_input_iscd="005930",
    fid_trgt_cls_code="111111111",
    fid_aply_rang_vol="0",
    fid_aply_rang_prc_2="0",
    fid_aply_rang_prc_1="0"
)

# %% [markdown]
# #### 7-13. 국내주식 신고_신저근접종목 상위 [v1_국내주식-105]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 신고_신저근접종목 상위[v1_국내주식-105]
##############################################################################################
ds.near_new_highlow(
    fid_aply_rang_vol="0",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_div_cls_code="0",
    fid_input_cnt_1="0",
    fid_input_cnt_2="0",
    fid_prc_cls_code="0",
    fid_input_iscd="005930",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000",
    fid_aply_rang_prc_1="0",
    fid_aply_rang_prc_2="0"
)

# %% [markdown]
# #### 7-14. 국내주식 배당률 상위 [국내주식-106]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 배당률 상위[국내주식-106]
##############################################################################################
ds.dividend_rate(
    cts_area="",
    gb1="0",
    upjong="0",
    gb2="0",
    gb3="0",
    f_dt="20250101",
    t_dt="20260226",
    gb4="0"
)

# %% [markdown]
# #### 7-15. 국내주식 대량체결건수 상위 [국내주식-107]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 대량체결건수 상위[국내주식-107]
##############################################################################################
ds.bulk_trans_num(
    fid_aply_rang_prc_2="0",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_rank_sort_cls_code="0",
    fid_div_cls_code="0",
    fid_input_price_1="0",
    fid_aply_rang_prc_1="0",
    fid_input_iscd_2="000000",
    fid_trgt_exls_cls_code="0000000000",
    fid_trgt_cls_code="111111111",
    fid_vol_cnt="0"
)

# %% [markdown]
# #### 7-16. 국내주식 신용잔고 상위 [국내주식-109]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 신용잔고 상위 [국내주식-109]
##############################################################################################
result1, result2 = ds.credit_balance(
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_option="0",
    fid_cond_mrkt_div_code="J",
    fid_rank_sort_cls_code="0"
)
print(result1)
print(result2)

# %% [markdown]
# #### 7-17. 국내주식 공매도 상위종목 [국내주식-133]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 공매도 상위종목[국내주식-133]
##############################################################################################
ds.short_sale(
    fid_aply_rang_vol="0",
    fid_cond_mrkt_div_code="J",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_period_div_code="D",
    fid_input_cnt_1="0",
    fid_trgt_exls_cls_code="0000000000",
    fid_trgt_cls_code="111111111",
    fid_aply_rang_prc_1="0",
    fid_aply_rang_prc_2="0"
)

# %% [markdown]
# #### 7-18. 국내주식 시간외등락율순위 [국내주식-138]

# %%
##############################################################################################
# [국내주식] 순위분석 > 국내주식 시간외등락율순위[국내주식-138]
##############################################################################################
result1, result2 = ds.overtime_fluctuation(
    fid_cond_mrkt_div_code="J",
    fid_mrkt_cls_code="K",
    fid_cond_scr_div_code="20171",
    fid_input_iscd="005930",
    fid_div_cls_code="0",
    fid_input_price_1="0",
    fid_input_price_2="0",
    fid_vol_cnt="0",
    fid_trgt_cls_code="111111111",
    fid_trgt_exls_cls_code="0000000000"
)
print(result1)
print(result2)

# %% [markdown]
# #### 7-19. HTS조회상위20종목 [국내주식-214]

# %%
##############################################################################################
# [국내주식] 순위분석 > HTS조회상위20종목[국내주식-214]
##############################################################################################
ds.hts_top_view()

# %% [markdown]
# ### **8. 실시간시세**

# %%
from kis.domestic_stock import domestic_stock_functions_ws as dsw

ka.auth_ws()
trenv = ka.getTREnv()

# 웹소켓 선언
kws = ka.KISWebSocket(api_url="/tryitout")
