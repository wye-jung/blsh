# %% [markdown]
# # [한국투자 Open API](https://apiportal.koreainvestment.com/apiservice-summary)

# %%
from wye.blsh.kis import kis_auth as ka
from wye.blsh.kis.overseas_stock import overseas_stock_functions as os

# 인증
# ka.auth(svr="vps")
ka.auth(svr="prod")
trenv = ka.getTREnv()

# %% [markdown]
# ## **해외주식**
# ---

# %% [markdown]
# ### **1. 주문/계좌**

# %% [markdown]
# #### 1-1. 해외주식 주문 [v1_해외주식-001]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 주문 [v1_해외주식-001]
##############################################################################################
os.order(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, ovrs_excg_cd="NASD", pdno="AAPL", ord_qty="10",
           ovrs_ord_unpr="150.00", ord_dv="sell", ctac_tlno="", mgco_aptm_odno="", ord_svr_dvsn_cd="0", ord_dvsn="00",
           env_dv="real")

# %% [markdown]
# #### 1-2. 해외주식 정정취소주문[v1_해외주식-003]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 정정취소주문[v1_해외주식-003]
##############################################################################################
os.order_rvsecncl(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, ovrs_excg_cd="NYSE", pdno="BA",
                    orgn_odno="1234567890", rvse_cncl_dvsn_cd="01", ord_qty="100", ovrs_ord_unpr="0", mgco_aptm_odno="",
                    ord_svr_dvsn_cd="0", env_dv="real")

# %% [markdown]
# #### 1-3. 해외주식 예약주문접수[v1_해외주식-002]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 예약주문접수[v1_해외주식-002]
##############################################################################################
os.order_resv(env_dv="real", ord_dv="usBuy", cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod,
                    pdno="TSLA", ovrs_excg_cd="NASD", ft_ord_qty="1", ft_ord_unpr3="900")

# %% [markdown]
# #### 1-4. 해외주식 예약주문접수취소[v1_해외주식-004]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 예약주문접수취소[v1_해외주식-004]
##############################################################################################
os.order_resv_ccnl(
    env_dv="real",
    nat_dv="us",
    cano=trenv.my_acct,
    acnt_prdt_cd=trenv.my_prod,
    rsvn_ord_rcit_dt="20250610",
    ovrs_rsvn_odno="0030008244"
)

# %% [markdown]
# #### 1-5. 해외주식 매수가능금액조회 [v1_해외주식-014]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 매수가능금액조회 [v1_해외주식-014]
##############################################################################################
os.inquire_psamount(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, ovrs_excg_cd="NASD", ovrs_ord_unpr="1.4",
                      item_cd="QQQ", env_dv="real")

# %% [markdown]
# #### 1-6. 해외주식 미체결내역 [v1_해외주식-005]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 미체결내역 [v1_해외주식-005]
##############################################################################################
os.inquire_nccs(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, ovrs_excg_cd="NASD", sort_sqn="DS", FK200="",
                  NK200="", env_dv="real")

# %% [markdown]
# #### 1-7. 해외주식 잔고 [v1_해외주식-006]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 잔고 [v1_해외주식-006]
##############################################################################################
os.inquire_balance(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, ovrs_excg_cd="NASD", tr_crcy_cd="USD")

# %% [markdown]
# #### 1-8. 해외주식 주문체결내역 [v1_해외주식-007]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 주문체결내역 [v1_해외주식-007]
##############################################################################################
os.inquire_ccnl(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, pdno="", ord_strt_dt="20250101",
                  ord_end_dt="20250131", sll_buy_dvsn="00", ccld_nccs_dvsn="00", ovrs_excg_cd="NASD", sort_sqn="DS",
                  ord_dt="", ord_gno_brno="", odno="", env_dv="real")

# %% [markdown]
# #### 1-9. 해외주식 체결기준현재잔고 [v1_해외주식-008]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 체결기준현재잔고 [v1_해외주식-008]
##############################################################################################
df1, df2, df3 = os.inquire_present_balance(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, wcrc_frcr_dvsn_cd="02",
                                        natn_cd="000", tr_mket_cd="00", inqr_dvsn_cd="00", env_dv="real")
print(df1)
print(df2)
print(df3)

# %% [markdown]
# #### 1-10. 해외주식 예약주문조회[v1_해외주식-013]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 예약주문조회[v1_해외주식-013]
##############################################################################################
os.order_resv_list(nat_dv="us", cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, inqr_strt_dt="20220809",
                     inqr_end_dt="20220830", inqr_dvsn_cd="00", ovrs_excg_cd="NASD")

# %% [markdown]
# #### 1-11. 해외주식 결제기준잔고 [해외주식-064]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 결제기준잔고 [해외주식-064]
##############################################################################################
df1, df2, df3 = os.inquire_paymt_stdr_balance(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, bass_dt="20250630",
                                           wcrc_frcr_dvsn_cd="01", inqr_dvsn_cd="00")
print(df1)
print(df2)
print(df3)

# %% [markdown]
# #### 1-12. 해외주식 일별거래내역 [해외주식-063]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 일별거래내역 [해외주식-063]
##############################################################################################
df1, df2 = os.inquire_period_trans(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, erlm_strt_dt="20240420",
                                erlm_end_dt="20240520", ovrs_excg_cd="NAS", pdno="", sll_buy_dvsn_cd="00",
                                loan_dvsn_cd="", FK100="", NK100="")
print(df1)
print(df2)

# %% [markdown]
# #### 1-13. 해외주식 기간손익 [v1_해외주식-032]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 기간손익 [v1_해외주식-032]
##############################################################################################
df1, df2 = os.inquire_period_profit(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, ovrs_excg_cd="NASD", natn_cd="",
                                 crcy_cd="USD", pdno="", inqr_strt_dt="20230101", inqr_end_dt="20231231",
                                 wcrc_frcr_dvsn_cd="01", FK200="", NK200="")
print(df1)
print(df2)

# %% [markdown]
# #### 1-14. 해외증거금 통화별조회 [해외주식-035]

# %%
##############################################################################################
# [해외주식] 주문/계좌 - 해외증거금 통화별조회 [해외주식-035]
##############################################################################################
os.foreign_margin(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod)

# %% [markdown]
# #### 1-15. 해외주식 미국주간주문 [v1_해외주식-026]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 미국주간주문 [v1_해외주식-026]
##############################################################################################
os.daytime_order(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, order_dv="buy", ovrs_excg_cd="NASD", pdno="AAPL",
                   ord_qty="10", ovrs_ord_unpr="150.50", ctac_tlno="", mgco_aptm_odno="", ord_svr_dvsn_cd="0",
                   ord_dvsn="00")

# %% [markdown]
# #### 1-16. 해외주식 미국주간정정취소 [v1_해외주식-027]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 미국주간정정취소 [v1_해외주식-027]
##############################################################################################
os.daytime_order_rvsecncl(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, ovrs_excg_cd="NASD", pdno="AAPL",
                            orgn_odno="1234567890", rvse_cncl_dvsn_cd="01", ord_qty="10", ovrs_ord_unpr="150.25",
                            ctac_tlno="", mgco_aptm_odno="", ord_svr_dvsn_cd="0")

# %% [markdown]
# #### 1-17. 해외주식 지정가주문번호조회 [해외주식-071]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 지정가주문번호조회 [해외주식-071]
##############################################################################################
os.algo_ordno(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, trad_dt="20250619")

# %% [markdown]
# #### 1-18. 해외주식 지정가체결내역조회 [해외주식-070]

# %%
##############################################################################################
# [해외주식] 주문/계좌 > 해외주식 지정가체결내역조회 [해외주식-070]
##############################################################################################
result, result3 = os.inquire_algo_ccnl(cano=trenv.my_acct, acnt_prdt_cd=trenv.my_prod, )
print(result)
print(result3)

# %% [markdown]
# ### **2. 기본시세**

# %% [markdown]
# #### 2-1. 해외주식 현재가상세[v1_해외주식-029]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식 현재가상세[v1_해외주식-029]
##############################################################################################
os.price_detail(auth="", excd="NAS", symb="TSLA")

# %% [markdown]
# #### 2-2. 해외주식 현재가 1호가[해외주식-033]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식 현재가 1호가[해외주식-033]
##############################################################################################
df1, df2, df3 = os.inquire_asking_price(auth="", excd="NAS", symb="TSLA")
print(df1)
print(df2)
print(df3)

# %% [markdown]
# #### 2-3. 해외주식 현재체결가[v1_해외주식-009]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식 현재체결가[v1_해외주식-009]
##############################################################################################
os.price(auth="", excd="NAS", symb="AAPL", env_dv="real")

# %% [markdown]
# #### 2-4. 해외주식 체결추이[해외주식-037]

# %% [markdown]
# #### 2-5. 해외주식분봉조회[v1_해외주식-030]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식분봉조회[v1_해외주식-030]
##############################################################################################
df1, df2 = os.inquire_time_itemchartprice(
    auth="",
    excd="NAS",
    symb="TSLA",
    nmin="5",
    pinc="1",
    next="",
    nrec="120",
    fill="",
    keyb="",
)
print(df1)
print(df2)

# %% [markdown]
# #### 2-6. 해외지수분봉조회 [v1_해외주식-031]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외지수분봉조회[v1_해외주식-031]
##############################################################################################
df1, df2 = os.inquire_time_indexchartprice(
    fid_cond_mrkt_div_code="N",
    fid_input_iscd="TSLA",
    fid_hour_cls_code="0",
    fid_pw_data_incu_yn="Y",
)
print(df1)
print(df2)

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식 체결추이[해외주식-037]
##############################################################################################
os.quot_inquire_ccnl(excd="NAS", tday="0", symb="TSLA")

# %% [markdown]
# #### 2-7. 해외주식 기간별시세[v1_해외주식-010]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식 기간별시세[v1_해외주식-010]
##############################################################################################
df1, df2 = os.dailyprice(
    auth="", excd="NAS", symb="TSLA", gubn="0", bymd="", modp="1", env_dv="real"
)
print(df1)
print(df2)

# %% [markdown]
# #### 2-8. 해외주식 종목_지수_환율기간별시세(일_주_월_년)[v1_해외주식-012]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식 종목_지수_환율기간별시세(일_주_월_년)[v1_해외주식-012]
##############################################################################################
df1, df2 = os.inquire_daily_chartprice(
    fid_cond_mrkt_div_code="N",
    fid_input_iscd=".DJI",
    fid_input_date_1="20250101",
    fid_input_date_2="20250131",
    fid_period_div_code="D",
    env_dv="real",
)
print(df1)
print(df2)

# %% [markdown]
# #### 2-9. 해외주식조건검색[v1_해외주식-015]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식조건검색[v1_해외주식-015]
##############################################################################################
df1, df2 = os.inquire_search(
    auth="",
    excd="NYS",
    co_yn_pricecur="1",
    co_st_pricecur="100",
    co_en_pricecur="200",
    co_yn_rate="1",
    co_st_rate="5",
    co_en_rate="10",
    co_yn_valx="1",
    co_st_valx="1000",
    co_en_valx="5000",
    co_yn_shar="1",
    co_st_shar="100",
    co_en_shar="500",
    co_yn_volume="1",
    co_st_volume="1000",
    co_en_volume="5000",
    co_yn_amt="1",
    co_st_amt="1000",
    co_en_amt="5000",
    co_yn_eps="1",
    co_st_eps="1",
    co_en_eps="5",
    co_yn_per="1",
    co_st_per="10",
    co_en_per="20",
    keyb="",
)
print(df1)
print(df2)

# %% [markdown]
# #### 2-10. 해외결제일자조회[해외주식-017]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외결제일자조회[해외주식-017]
##############################################################################################
os.countries_holiday(trad_dt="20250131", NK="", FK="")

# %% [markdown]
# #### 2-11. 해외주식 상품기본정보[v1_해외주식-034]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식 상품기본정보[v1_해외주식-034]
##############################################################################################
os.search_info(prdt_type_cd="512", pdno="AAPL")

# %% [markdown]
# #### 2-12. 해외주식 업종별시세[해외주식-048]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식 업종별시세[해외주식-048]
##############################################################################################
result1, result2 = os.industry_theme(excd="NAS", icod="010", vol_rang="0")
print(result1)
print(result2)

# %% [markdown]
# #### 2-13. 해외주식 업종별코드조회[해외주식-049]

# %%
##############################################################################################
# [해외주식] 기본시세 > 해외주식 업종별코드조회[해외주식-049]
##############################################################################################
result1, result2 = os.industry_price(excd="NAS")
print(result1)
print(result2)

# %% [markdown]
# ### **3. 시세분석**

# %% [markdown]
# #### 3-1. 해외주식 가격급등락[해외주식-038]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 가격급등락[해외주식-038]
##############################################################################################
result1, result2 = os.price_fluct(excd="NAS", gubn="0", mixn="0", vol_rang="0")
print(result1)
print(result2)

# %% [markdown]
# #### 3-2. 해외주식 거래량급증[해외주식-039]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 거래량급증[해외주식-039]
##############################################################################################
result1, result2 = os.volume_surge(excd="NYS", mixn="0", vol_rang="0")
print(result1)
print(result2)

# %% [markdown]
# #### 3-3. 해외주식 매수체결강도상위[해외주식-040]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 매수체결강도상위[해외주식-040]
##############################################################################################
result1, result2 = os.volume_power(excd="HKS", nday="0", vol_rang="0")
print(result1)
print(result2)

# %% [markdown]
# #### 3-4. 해외주식 상승률/하락률[해외주식-041]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 상승률/하락률[해외주식-041]
##############################################################################################
result1, result2 = os.updown_rate(excd="SHS", gubn="1", nday="0", vol_rang="0")
print(result1)
print(result2)

# %% [markdown]
# #### 3-5. 해외주식 거래량순위[해외주식-043]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 거래량순위[해외주식-043]
##############################################################################################
result1, result2 = os.trade_vol(excd="HNX", nday="0", vol_rang="0")
print(result1)
print(result2)

# %% [markdown]
# #### 3-6. 해외주식 신고/신저가[해외주식-042]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 신고/신저가[해외주식-042]
##############################################################################################
result1, result2 = os.new_highlow(excd="AMS", mixn="0", vol_rang="0", gubn="1", gubn2="1")
print(result1)
print(result2)

# %% [markdown]
# #### 3-7. 해외주식 거래증가율순위[해외주식-045]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 거래증가율순위[해외주식-045]
##############################################################################################
result1, result2 = os.trade_growth(excd="NAS", nday="0", vol_rang="0")
print(result1)
print(result2)

# %% [markdown]
# #### 3-8. 해외주식 거래회전율순위[해외주식-046]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 거래회전율순위[해외주식-046]
##############################################################################################
result1, result2 = os.trade_turnover(excd="SHS", nday="0", vol_rang="0")
print(result1)
print(result2)

# %% [markdown]
# #### 3-9. 해외주식 거래대금순위[해외주식-044]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 거래대금순위[해외주식-044]
##############################################################################################
result1, result2 = os.trade_pbmn(excd="NAS", nday="0", vol_rang="0")
print(result1)
print(result2)

# %% [markdown]
# #### 3-10. 해외주식 시가총액순위[해외주식-047]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 시가총액순위[해외주식-047]
##############################################################################################
result1, result2 = os.market_cap(excd="SZS", vol_rang="1")
print(result1)
print(result2)

# %% [markdown]
# #### 3-11. 해외주식 기간별권리조회 [해외주식-052]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 기간별권리조회 [해외주식-052]
##############################################################################################
os.period_rights(
    rght_type_cd="%%",
    inqr_dvsn_cd="02",
    inqr_strt_dt="20240417",
    inqr_end_dt="20240417",
)

# %% [markdown]
# #### 3-12. 해외주식 권리종합 [해외주식-050]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외주식 권리종합 [해외주식-050]
##############################################################################################
os.rights_by_ice(ncod="US", symb="NVDL")

# %% [markdown]
# #### 3-13. 당사 해외주식담보대출 가능 종목 [해외주식-051]

# %%
##############################################################################################
# [해외주식] 시세분석 > 당사 해외주식담보대출 가능 종목 [해외주식-051]
##############################################################################################
result1, result2 = os.colable_by_company(pdno="AMD", natn_cd="840", inqr_sqn_dvsn="01")
print(result1)
print(result2)

# %% [markdown]
# #### 3-14. 해외뉴스종합(제목) [해외주식-053]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외뉴스종합(제목) [해외주식-053]
##############################################################################################
os.news_title(
    info_gb="",
    class_cd="",
    nation_cd="",
    exchange_cd="",
    symb="",
    data_dt="",
    data_tm="",
    cts=""
)

# %% [markdown]
# #### 3-15. 해외속보(제목) [해외주식-055]

# %%
##############################################################################################
# [해외주식] 시세분석 > 해외속보(제목) [해외주식-055]
##############################################################################################
os.brknews_title(fid_news_ofer_entp_code="0", fid_cond_scr_div_code="11801")

# %% [markdown]
# ### **4. 실시간시세**
